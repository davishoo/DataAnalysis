# %%
quotation = pd.ExcelFile('quotationData.xlsx')
pd.read_excel(quotation, 'Sheet1')
# Out:
#   项目(Project) 报价来源(quotationSource) 酒店名称(Hotel) 房型(RoomType) 报价日期(QuoteDate)  \
# 0  2019年6月珠宝展                  酒店销售     港岛太平洋酒店         高級客房      2019-05-16
# 1  2019年6月珠宝展                  酒店销售         酒店2         高級客房      2019-05-16
# 2         项目2                    携程     港岛太平洋酒店         高級客房      2019-05-16
# 3         项目3                    艺龙     港岛太平洋酒店         高級客房      2019-05-16
# 4         项目3                    艺龙     港岛太平洋酒店         高級客房      2019-05-16
#
#   截止日期(ExpireDate)  2019-6-19 （Day1)  2019-6-20(Day2)  2019-6-21(Day3)  \
# 0       2019-05-31               700              700              700
# 1       2019-05-31               700              700              700
# 2       2019-05-31               700              700              700
# 3       2019-05-31               800              800              800
# 4       2019-06-01               900              800              800
#
#    2019-6-22(Day4) 税(Tax) 早餐(Breakfast)  早餐价格(breakfastPrice)  \
# ...

# %%
import pandas as pd
frame = pd.read_excel('quotationData.xlsx', 'Sheet1')
frame
# Out:
#   项目(Project) 报价来源(quotationSource) 酒店名称(Hotel) 房型(RoomType) 报价日期(QuoteDate)  \
# 0  2019年6月珠宝展                  酒店销售     港岛太平洋酒店         高級客房      2019-05-16
# 1  2019年6月珠宝展                  酒店销售         酒店2         高級客房      2019-05-16
# 2         项目2                    携程     港岛太平洋酒店         高級客房      2019-05-16
# 3         项目3                    艺龙     港岛太平洋酒店         高級客房      2019-05-16
# 4         项目3                    艺龙     港岛太平洋酒店         高級客房      2019-05-16
#
#   截止日期(ExpireDate)  2019-6-19 （Day1)  2019-6-20(Day2)  2019-6-21(Day3)  \
# 0       2019-05-31               700              700              700
# 1       2019-05-31               700              700              700
# 2       2019-05-31               700              700              700
# 3       2019-05-31               800              800              800
# 4       2019-06-01               900              800              800
#
#    2019-6-22(Day4) 税(Tax) 早餐(Breakfast)  早餐价格(breakfastPrice)  \
# ...

# %%
writer = pd.ExcelWriter('quotationOutput1.xlsx')
frame.to_excel(writer, 'Sheet1', index = False)
writer.save()
